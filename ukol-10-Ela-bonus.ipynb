# %%
import pandas
import matplotlib.pyplot as plt

# %%
#Nepovinný bonus 1
teploty = pandas.read_csv("temperature.csv")
teplota_ve_mestech = teploty[teploty["City"].isin(["Helsinki","Miami Beach","Tokyo"])]

# %%
teplota_ve_mestech.boxplot(column="AvgTemperature", by="City", figsize=(8, 8))

plt.show()
